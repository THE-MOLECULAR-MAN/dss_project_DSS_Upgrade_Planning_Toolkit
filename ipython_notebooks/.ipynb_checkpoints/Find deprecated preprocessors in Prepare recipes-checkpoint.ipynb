# %%
import dataiku
from pprint import pprint as pp

# %%
client = dataiku.api_client()

# %%
def get_unique_types(data_list: list[dict]) -> list:
    """
    Extracts unique values from the 'type' key within a list of dictionaries.
    
    Args:
        data_list (list[dict]): A list of dictionaries, each potentially containing a 'type' key.
        
    Returns:
        list: A sorted list of unique 'type' values found in the input.
    """
    # Use a set comprehension for O(n) extraction and automatic deduplication
    # We use .get() to handle cases where 'type' might be missing, filtering out None
    unique_types = {item.get('type') for item in data_list if 'type' in item}
    
    # Return as a sorted list for consistent, deterministic output
    return sorted(list(unique_types))

# --- Example Usage ---
# d = [{'type': 'S3'}, {'type': 'Managed'}, {'type': 'S3'}]
# unique_values = get_unique_types(d)
# print(unique_values)

# %%
for pk in client.list_project_keys():
    project_handle = client.get_project(pk)
    
    # https://developer.dataiku.com/latest/api-reference/python/recipes.html#dataikuapi.dss.recipe.DSSRecipe
    for recipe_handle in project_handle.list_recipes(as_type="objects"):
            
        # https://developer.dataiku.com/latest/api-reference/python/recipes.html#dataikuapi.dss.recipe.DSSRecipeSettings
        recipe_settings_handle = recipe_handle.get_settings()
        recipe_type = recipe_settings_handle.type
        if recipe_type == 'shaker': # prepare recipe
            print(f"found shaker")
            #raw_data = recipe_settings_handle.get_recipe_raw_definition()
            #pp(raw_data)
            prepare_recipe_payload = recipe_settings_handle.obj_payload
            steps = prepare_recipe_payload.get("steps",[])
            preprocessors_unique = get_unique_types(steps)
            print(preprocessors_unique)
            
#             pp(prepare_recipe_payload)
